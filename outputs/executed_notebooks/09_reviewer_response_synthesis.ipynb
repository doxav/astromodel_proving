# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/doxav/astromodel_proving/blob/main/analysis/09_reviewer_response_synthesis.ipynb)
#
# # Step 09 - Reviewer-response synthesis
#
# This notebook integrates Steps 00-08 into reviewer-facing traceability, claim-maturity, and manuscript asset tables. It creates no new biological evidence and does not upgrade claims beyond what upstream outputs support.

# %%
from pathlib import Path
import os
import pandas as pd

PROJECT_ROOT = Path(os.environ.get("ASTROMODEL_PROJECT_ROOT", ".")).resolve()
PROJECT_ROOT
# Out:
# PosixPath('/home/xav/code/astromodel_proving')

# %%
from src.step09_reviewer_synthesis import Step09Config, run_step09_reviewer_synthesis

config = Step09Config(write_outputs=True)
result = run_step09_reviewer_synthesis(PROJECT_ROOT, config)
result["analysis_summary"]
# Out:
# {'step_name': 'Step 09 - reviewer-response synthesis',
#  'config': {'write_outputs': True},
#  'n_reviewer_rows': 7,
#  'n_claim_rows': 6,
#  'n_manifest_rows': 12,
#  'missing_manifest_artifacts': [],
#  'final_biological_degeneracy_claim_allowed': False,
#  'headline_claim_scope': 'Final degeneracy wording is allowed only if all upstream evidence layers are supported.',
#  'elapsed_seconds': 0.023015669001324568}

# %% [markdown]
# ## R1-R7 traceability

# %%
traceability = result["reviewer_traceability_table"]
traceability
# Out:
#   reviewer_id                                           critique  \
# 0          R1   degeneracy versus non-identifiability/sloppiness
# 1          R2  experimental variability, noise, and data cons...
# 2          R3               model assumptions and proxy validity
# 3          R4  Vm-only fits and physiological parameter plaus...
# 4          R5               pathways, mechanisms, and phenotypes
# 5          R6    held-out prediction and perturbation robustness
# 6          R7  clarity, organization, units, and figure trace...
#
#                                      primary_outputs evidence_status  \
# 0  outputs/identifiability; outputs/mechanisms; o...       supported
# 1               outputs/provenance; outputs/features       supported
# 2                     outputs/assumption_sensitivity         partial
# 3  outputs/identifiability; outputs/parameter_pla...       supported
# 4  outputs/mechanisms; outputs/predictive_validation       supported
# 5                      outputs/predictive_validation       supported
# 6  outputs/reviewer_synthesis/manuscript_asset_ma...       supported
#
#                                       claim_boundary  \
# 0  Degeneracy wording remains disabled unless Ste...
# 1  Cell/file is the independent unit; no paired a...
# 2  Explicit ECS/proxy variants remain required wh...
# 3  Raw parameters are interpreted only when range...
# 4  Phenotype tags are provisional until predictio...
# 5  Prediction-limited or fit-only clusters are no...
# 6  Figures/tables must cite source step outputs a...
#
#    final_biological_degeneracy_claim_allowed
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False

# %% [markdown]
# ## Claim maturity

# %%
maturity = result["claim_maturity_table"]
maturity
# Out:
#                                                claim  \
# 0   accepted cell-specific six-sweep ensembles exist
# 1  candidate mechanism regimes are biologically i...
# 2  mechanism or phenotype labels are predictive u...
# 3      model assumptions do not drive the conclusion
# 4  accepted parameters are physiologically interp...
# 5     final biological degeneracy wording is allowed
#
#                         maturity  \
# 0                      supported
# 1        candidate_regime_screen
# 2                      supported
# 3  model_dependent_or_unresolved
# 4                        partial
# 5                not_allowed_yet
#
#                                                basis  \
# 0  Step 04 accepted ensemble and held-out-current...
# 1  Step 05 hidden-current, windowed phenotype, cl...
# 2  Step 06 robustness labels and biological_descr...
# 3  Step 07 gating, proxy, and compartment-split s...
# 4  Step 08 range, identifiability, and constraine...
# 5                    Integrated Step 03-08 synthesis
#
#                                remaining_requirement  \
# 0  increase accepted/reviewer-facing cell coverag...
# 1  requires Step 06 predictive/perturbation suppo...
# 2  broaden support across region, condition, mech...
# 3  explicit ECS variant or additional data if pro...
# 4  raw coordinates require both range and identif...
# 5  requires mechanism distinction, predictive sup...
#
#    mean_biological_description_score
# 0                           0.657225
# 1                           0.657225
# 2                           0.657225
# 3                           0.657225
# 4                           0.657225
# 5                           0.657225

# %% [markdown]
# ## Manuscript asset manifest

# %%
manifest = result["manuscript_asset_manifest"]
manifest
# Out:
#        step                                           artifact  \
# 0   Step 00  outputs/provenance/atf_region_condition_invent...
# 1   Step 02  outputs/features/condition_region_sweep_thresh...
# 2   Step 03  outputs/identifiability/effective_parameter_ma...
# 3   Step 04      outputs/cell_fits/accepted_cell_ensembles.csv
# 4   Step 04          outputs/cell_fits/cell_fit_candidates.csv
# 5   Step 05     outputs/mechanisms/accepted_fit_mechanisms.csv
# 6   Step 05  outputs/mechanisms/accepted_fit_mechanisms_win...
# 7   Step 05    outputs/mechanisms/buffering_phenotype_tags.csv
# 8   Step 06  outputs/predictive_validation/robustness_summa...
# 9   Step 07  outputs/assumption_sensitivity/claim_scope_tab...
# 10  Step 08  outputs/parameter_plausibility/interpretabilit...
# 11  Step 09  outputs/reviewer_synthesis/reviewer_traceabili...
#
#                                               purpose  exists  \
# 0      ATF data provenance and region/condition audit    True
# 1                     Region-aware feature thresholds    True
# 2   Effective-parameter and identifiability guardr...    True
# 3                   Accepted six-sweep cell ensembles    True
# 4                    Full candidate history for audit    True
# 5                   Hidden-current flux decomposition    True
# 6   Windowed local/spatial mechanism characterization    True
# 7                          Provisional phenotype tags    True
# 8              Prediction and perturbation robustness    True
# 9                  Assumption-sensitivity claim scope    True
# 10              Parameter interpretability guardrails    True
# 11                                 R1-R7 response map    True
#
#                      claim_scope
# 0   reviewer_facing_source_table
# 1   reviewer_facing_source_table
# 2   reviewer_facing_source_table
# 3   reviewer_facing_source_table
# 4   reviewer_facing_source_table
# 5   reviewer_facing_source_table
# 6   reviewer_facing_source_table
# 7   reviewer_facing_source_table
# 8   reviewer_facing_source_table
# 9   reviewer_facing_source_table
# 10  reviewer_facing_source_table
# 11  reviewer_facing_source_table

# %% [markdown]
# ## Objective synthesis conclusion
#
# The final row below is generated from the actual upstream outputs. If final biological degeneracy wording is not allowed, the manuscript response should keep the claim at mechanism-screen or prediction-limited maturity and state the unresolved layer explicitly.

# %%
final_claim = maturity[maturity["claim"].eq("final biological degeneracy wording is allowed")]
display(final_claim)
assert set(traceability["reviewer_id"]) == {"R1", "R2", "R3", "R4", "R5", "R6", "R7"}
assert "final_biological_degeneracy_claim_allowed" in result["analysis_summary"]
print("Step 09 synthesis outputs written under", PROJECT_ROOT / "outputs" / "reviewer_synthesis")
# Out:
#                                             claim         maturity  \
# 5  final biological degeneracy wording is allowed  not_allowed_yet
#
#                              basis  \
# 5  Integrated Step 03-08 synthesis
#
#                                remaining_requirement  \
# 5  requires mechanism distinction, predictive sup...
#
#    mean_biological_description_score
# 5                           0.657225
# Step 09 synthesis outputs written under /home/xav/code/astromodel_proving/outputs/reviewer_synthesis

# %% [markdown]
# ## Post-execution scientific status
#
# Executed status for reviewer response: Step 09 integrates R1-R7 into 7 traceability rows, 6 claim-maturity rows, and a complete 12-artifact manuscript manifest with no missing artifacts. The integrated maturity table marks accepted ensembles and predictive/perturbation evidence as supported, mechanism regimes as a candidate screen, assumptions as model-dependent/unresolved, parameter interpretability as partial, and final biological degeneracy wording as `not_allowed_yet`. This is the current objective model-proving state.
